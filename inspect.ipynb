# %%
import pandas as pd

# %%
f = '/home/disk/tc/pangulo/UW_GPM_Precipitation_Feature_Dataset/AFC/gpm_pf_stats.AFC.2015.01.csv'
df = pd.read_csv(f)
df.where(df['is_complete']).dropna()
# Out:
#                                            gpm_filename  feature_id  \
# 0     /home/disk/archive3/gpm/v07/AFC/interp_data/20...         1.0
# 1     /home/disk/archive3/gpm/v07/AFC/interp_data/20...         2.0
# 2     /home/disk/archive3/gpm/v07/AFC/interp_data/20...         6.0
# 3     /home/disk/archive3/gpm/v07/AFC/interp_data/20...         2.0
# 4     /home/disk/archive3/gpm/v07/AFC/interp_data/20...         3.0
# ...                                                 ...         ...
# 7670  /home/disk/archive3/gpm/v07/AFC/interp_data/20...        38.0
# 7672  /home/disk/archive3/gpm/v07/AFC/interp_data/20...        49.0
# 7673  /home/disk/archive3/gpm/v07/AFC/interp_data/20...        51.0
# 7674  /home/disk/archive3/gpm/v07/AFC/interp_data/20...        53.0
# 7675  /home/disk/archive3/gpm/v07/AFC/interp_data/20...        55.0
#
#      is_complete   observation_time  mean_latitude  mean_longitude  \
# 0           True  20150101_00:08:23     -39.829411      -29.955883
# ...

# %%
f = '/home/disk/tc/pangulo/gpm_precipitation_feature_database/AFC/gpm_pf_stats.AFC.2015.01.csv'
df = pd.read_csv(f)
df
# Out:
#                                            gpm_filename  feature_id  \
# 0     /home/disk/archive3/gpm/v07/AFC/interp_data/20...           1
# 1     /home/disk/archive3/gpm/v07/AFC/interp_data/20...           2
# 2     /home/disk/archive3/gpm/v07/AFC/interp_data/20...           6
# 3     /home/disk/archive3/gpm/v07/AFC/interp_data/20...           2
# 4     /home/disk/archive3/gpm/v07/AFC/interp_data/20...           3
# ...                                                 ...         ...
# 6034  /home/disk/archive3/gpm/v07/AFC/interp_data/20...          38
# 6035  /home/disk/archive3/gpm/v07/AFC/interp_data/20...          49
# 6036  /home/disk/archive3/gpm/v07/AFC/interp_data/20...          51
# 6037  /home/disk/archive3/gpm/v07/AFC/interp_data/20...          53
# 6038  /home/disk/archive3/gpm/v07/AFC/interp_data/20...          55
#
#        observation_time  mean_latitude  mean_longitude  \
# 0     20150101_00:08:23     -39.829411      -29.955883
# ...
