# %%
import pandas as pd

# %%
f = '/home/disk/tc/pangulo/UW_GPM_Precipitation_Feature_Dataset/AFC/gpm_pf_stats.AFC.2014.10.csv'
df = pd.read_csv(f)
df
# Out:
#                                            gpm_filename  feature_id  \
# 0     /home/disk/archive3/gpm/v07/AFC/interp_data/20...           3
# 1     /home/disk/archive3/gpm/v07/AFC/interp_data/20...           4
# 2     /home/disk/archive3/gpm/v07/AFC/interp_data/20...           6
# 3     /home/disk/archive3/gpm/v07/AFC/interp_data/20...           7
# 4     /home/disk/archive3/gpm/v07/AFC/interp_data/20...          15
# ...                                                 ...         ...
# 7437  /home/disk/archive3/gpm/v07/AFC/interp_data/20...          86
# 7438  /home/disk/archive3/gpm/v07/AFC/interp_data/20...          87
# 7439  /home/disk/archive3/gpm/v07/AFC/interp_data/20...          88
# 7440  /home/disk/archive3/gpm/v07/AFC/interp_data/20...          28
# 7441  /home/disk/archive3/gpm/v07/AFC/interp_data/20...          49
#
#       is_complete   observation_time  mean_latitude  mean_longitude  \
# 0            True  20141001_01:18:29      -6.315080       14.526190
# ...

# %%
f = '/home/disk/tc/pangulo/UW_GPM_Precipitation_Feature_Dataset/AFC/gpm_pf_stats.AFC.2014.10.csv'
df = pd.read_csv(f)
df
